# %%
def simple_interest(p,r,t):
    si=(p*r*t)/100
    return si
def compound_interest(p,r,t):
    amount=p*(1+r/100)**t
    ci=amount-p
    return ci
n=int(input("enter the number of customers"))
for i in range(n):
    print("\n customers",i+1)
    p=int(input("enter the principle:"))
    r=int(input("enter the rate:"))
    t=int(input("enter the time:"))
    si=simple_interest(p,r,t)
    ci=compound_interest(p,r,t)
    print("simple_interest",si)
    print("compound_interest",ci)
# Out:
# enter the number of customers 3
#  customers 1
# enter the principle: 1
# enter the rate: 1
# enter the time: 1
# simple_interest 0.01
# compound_interest 0.010000000000000009
#
#  customers 2
# enter the principle: 3
# enter the rate: 4
# enter the time: 5
# simple_interest 0.6
# compound_interest 0.6499587072000006
#
#  customers 3
# enter the principle: 3
# enter the rate: 5
# enter the time: 6
# simple_interest 0.9
# compound_interest 1.0202869218750017
